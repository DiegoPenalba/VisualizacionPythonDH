# %%
# Importar las librerías necesarias
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('train_clean.csv')

# %%
df
# Out:
#       Age Cabin Embarked     Fare  \
# 0    22.0   NaN        S   7.2500
# 1    38.0   C85        C  71.2833
# 2    26.0   NaN        S   7.9250
# 3    35.0  C123        S  53.1000
# 4    35.0   NaN        S   8.0500
# ..    ...   ...      ...      ...
# 886  27.0   NaN        S  13.0000
# 887  19.0   B42        S  30.0000
# 888  22.0   NaN        S  23.4500
# 889  26.0  C148        C  30.0000
# 890  32.0   NaN        Q   7.7500
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# ..                                                 ...    ...          ...
# ...

# %% [markdown]
# #### Features Description
#
# * PassengerId: Identificador único para cada pasajero.
# * Survived: Indicador de si el pasajero sobrevivió (1) o no (0).
# * Pclass: Clase del billete del pasajero (1, 2 o 3), representando la clase de viaje.
# * Name: Nombre completo del pasajero.
# * Sex: Género del pasajero (masculino o femenino).
# * Age: Edad del pasajero en años.
# * SibSp: Número de hermanos/cónyuges a bordo con el pasajero.
# * Parch: Número de padres/hijos a bordo con el pasajero.
# * Ticket: Número del billete.
# * Fare: Tarifa pagada por el billete.
# * Cabin: Número de cabina asignada al pasajero (puede ser NaN si no se asignó).
# * Embarked: Puerto de embarque (C = Cherbourg, Q = Queenstown, S = Southampton).
# * Family_Size: Tamaño de la familia

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  Family_Size
# 0       3    male      1       0.0         A/5 21171    Mr            1
# 1       1  female      1       1.0          PC 17599   Mrs            1
# 2       3  female      0       1.0  STON/O2. 3101282  Miss            0
# ...

# %%
df.tail()
# Out:
#       Age Cabin Embarked   Fare                                      Name  \
# 886  27.0   NaN        S  13.00                     Montvila, Rev. Juozas
# 887  19.0   B42        S  30.00              Graham, Miss. Margaret Edith
# 888  22.0   NaN        S  23.45  Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0  C148        C  30.00                     Behr, Mr. Karl Howell
# 890  32.0   NaN        Q   7.75                       Dooley, Mr. Patrick
#
#      Parch  PassengerId  Pclass     Sex  SibSp  Survived      Ticket Title  \
# 886      0          887       2    male      0       0.0      211536   Rev
# 887      0          888       1  female      0       1.0      112053  Miss
# 888      2          889       3  female      1       0.0  W./C. 6607  Miss
# 889      0          890       1    male      0       1.0      111369    Mr
# 890      0          891       3    male      0       0.0      370376    Mr
#
#      Family_Size
# 886            0
# 887            0
# ...

# %%
df.dtypes
# Out:
# Age            float64
# Cabin              str
# Embarked           str
# Fare           float64
# Name               str
# Parch            int64
# PassengerId      int64
# Pclass           int64
# Sex                str
# SibSp            int64
# Survived       float64
# Ticket             str
# Title              str
# Family_Size      int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          891 non-null    float64
#  1   Cabin        204 non-null    str
#  2   Embarked     891 non-null    str
#  3   Fare         891 non-null    float64
#  4   Name         891 non-null    str
#  5   Parch        891 non-null    int64
#  6   PassengerId  891 non-null    int64
#  7   Pclass       891 non-null    int64
#  8   Sex          891 non-null    str
#  9   SibSp        891 non-null    int64
#  10  Survived     891 non-null    float64
#  11  Ticket       891 non-null    str
#  12  Title        891 non-null    str
#  13  Family_Size  891 non-null    int64
# dtypes: float64(3), int64(5), str(6)
# memory usage: 97.6 KB

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0.0    549
# 1.0    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Proporción de Supervivientes')
plt.ylabel('')
plt.show()

# %%
df['Pclass'].value_counts().sort_index().plot(kind='bar')
plt.title('Número de pasajeros por clase')
plt.xlabel('Clase')
plt.ylabel('Cantidad')
plt.show()

# %%
sns.countplot(x='Pclass', data=df, hue='Pclass', legend=False, palette='pastel')
plt.title('Número de pasajeros por clase')
plt.xlabel('Clase')
plt.ylabel('Cantidad')
plt.show()

# %%
df.Age.value_counts().sort_index()
# Out:
# Age
# 0.42     1
# 0.67     1
# 0.75     2
# 0.83     2
# 0.92     1
#         ..
# 70.00    2
# 70.50    1
# 71.00    2
# 74.00    1
# 80.00    1
# Name: count, Length: 89, dtype: int64

# %%
plt.hist(df['Age'], bins=20, edgecolor='k')
plt.title('Distribución  de Edad de lo pasajeros')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
sns.boxplot(x='Survived', y='Age', data=df, hue='Survived', legend=False, palette='pastel')
plt.title('Sobrevivientes por edad')
plt.xlabel('Sobrevivió')
plt.ylabel('Edad')
plt.show()

# %%
sns.countplot(x='Survived', hue='Sex', data=df, palette='pastel')
plt.title('Supervivientes por género')
plt.xlabel('Sobrevivió')
plt.ylabel('Cantidad')
plt.show()

# %%
sns.countplot(x='Survived', hue='Pclass', data=df, palette='pastel')
plt.title('Supervivientes por clase')
plt.xlabel('Sobrevivió')
plt.ylabel('Cantidad')
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=df, palette='pastel')
plt.title('Supervivientes por clase')
plt.xlabel('Sobrevivió')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# Las personas de tercera clase sobrevivieron en menor proporción que las de primera clase.

# %%
plt.scatter(df['Age'], df['Fare'], alpha=0.5)
plt.title('Relación entre edad y tarifa')
plt.xlabel('Edad')
plt.ylabel('Tarifa')
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', data=df)
plt.title('Distribución de tarifas por clase')
plt.xlabel('Clase')
plt.ylabel('Tarifa')
plt.show()

# %%
correlation_matrix = df.corr() # Hay valores que no son numericos, por lo que no se puede mostrar la matriz. 
sns.heatmap(correlation_matrix)
plt.title('Heatmap de correlación') 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 correlation_matrix = df.corr()
#       2 sns.heatmap(correlation_matrix)
#       3 plt.title('Heatmap de correlación')
#
# File ~/Workspace/VisualizacionPythonDH/viz_env/lib/python3.11/site-packages/pandas/core/frame.py:13117, in DataFrame.corr(self, method, min_periods, numeric_only)
#   13115 cols = data.columns
#   13116 idx = cols.copy()
# > 13117 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   13119 if method == "pearson":
#   13120     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Workspace/VisualizacionPythonDH/viz_env/lib/python3.11/site-packages/pandas/core/frame.py:2081, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2079 if dtype is not None:
#    2080     dtype = np.dtype(dtype)
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number])


correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap de correlación')
plt.show()

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  Family_Size
# 0       3    male      1       0.0         A/5 21171    Mr            1
# 1       1  female      1       1.0          PC 17599   Mrs            1
# 2       3  female      0       1.0  STON/O2. 3101282  Miss            0
# ...

# %%
sns.countplot(x='Embarked', data=df, palette='pastel')
plt.title('Cantidad de pasajeros por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Cantidad')
plt.show()
# Out:
# /var/folders/py/337h4wz56hv29t1tbtztkpp80000gq/T/ipykernel_77513/780800837.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Embarked', data=df, palette='pastel')

# %%
sns.catplot(x='Pclass', col='Embarked', data=df, kind='count', hue='Pclass', legend=False, palette='pastel')
plt.suptitle('Cantidad de pasajeros Clase y Puerto de Embarque', y=1.05)
plt.show()

# %%
sns.pairplot(df, hue='Survived', vars=['Age', 'Fare', 'Pclass'], palette='pastel')
plt.suptitle('Pairplot de Variables numéricas por supervivencia', y=1.05)
plt.show()

# %%
g = sns.FacetGrid(df, col='Pclass', row='Sex', margin_titles=True)
g.map(plt.hist, 'Age', bins=20, color='green')
g.fig.suptitle('Distribución de edad por clase y sexo', y=1.05)
plt.show()

# %%
sns.jointplot(x='Age', y='Fare', data=df, kind='kde', fill=True)
plt.suptitle('Relación entre edad y tarifa', y=1.05)
plt.show()

# %%
df.head()
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket Title  Family_Size
# 0       3    male      1       0.0         A/5 21171    Mr            1
# 1       1  female      1       1.0          PC 17599   Mrs            1
# 2       3  female      0       1.0  STON/O2. 3101282  Miss            0
# ...

# %%
sns.countplot(x='Family_Size', hue='Survived', data=df, palette='pastel')
plt.title('Supervivencia por tamaño de familia')
plt.xlabel('Tamaño de la familia')
plt.ylabel('Cantidad')
plt.show()

# %%
numeric_df
# Out:
#       Age     Fare  Parch  PassengerId  Pclass  SibSp  Survived  Family_Size
# 0    22.0   7.2500      0            1       3      1       0.0            1
# 1    38.0  71.2833      0            2       1      1       1.0            1
# 2    26.0   7.9250      0            3       3      0       1.0            0
# 3    35.0  53.1000      0            4       1      1       1.0            1
# 4    35.0   8.0500      0            5       3      0       0.0            0
# ..    ...      ...    ...          ...     ...    ...       ...          ...
# 886  27.0  13.0000      0          887       2      0       0.0            0
# 887  19.0  30.0000      0          888       1      0       1.0            0
# 888  22.0  23.4500      2          889       3      1       0.0            3
# 889  26.0  30.0000      0          890       1      0       1.0            0
# 890  32.0   7.7500      0          891       3      0       0.0            0
#
# [891 rows x 8 columns]

# %%
correlation_matrix = numeric_df.corr()
sns.clustermap(correlation_matrix, annot=True, cmap='viridis', figsize=(6, 6))
plt.title('Clustermap de correlación')
plt.show()

# %%
fig = plt.figure(figsize=(20, 6))
gs = gridspec.GridSpec(nrows=1, ncols=3, figure=fig)

ax1 =fig.add_subplot(gs[0, 0])
sns.histplot(df['Age'], kde=True)

ax2 =fig.add_subplot(gs[0, 1])
sns.boxplot(x='Pclass', y='Age', hue='Sex', data=df, palette='pastel')

ax3 =fig.add_subplot(gs[0, 2])
sns.swarmplot(x='Pclass', y='Age', hue='Survived', data=df, dodge=True, palette='pastel')
plt.legend(title='Sobrevivió?', labels=['No', 'Si'])
# Out:
# /Users/dieh.penalba/Workspace/VisualizacionPythonDH/viz_env/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 27.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/dieh.penalba/Workspace/VisualizacionPythonDH/viz_env/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 30.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/dieh.penalba/Workspace/VisualizacionPythonDH/viz_env/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(x='Pclass', y='Age', hue='Survived', data=df, palette='viridis')
plt.title('Distribución de edad por clase y supervivencia')
plt.xlabel('Clase')
plt.ylabel('Edad')
plt.show()

# %% [markdown]
# Las personas que más sobrevivieron pertenecian a primera clase, tenían menos edad y eran mayormente mujeres.
